# %%
# Data manipulation and processing
import pandas as pd
import numpy as np
import random
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# Machine learning models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# Neural network (Deep Learning)
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        26.0          male        Associate       256862.0               2
# 1        23.0        female        Associate        70430.0               0
# 2        33.0          male        Associate        75456.0              10
# 3        27.0        female        Associate        25052.0               7
# 4        30.0        female         Bachelor        61291.0               8
#
#   person_home_ownership  loan_amnt        loan_intent  loan_int_rate  \
# 0              MORTGAGE    35000.0          EDUCATION          10.65
# 1              MORTGAGE     6455.0            VENTURE          10.24
# 2                  RENT     7000.0            MEDICAL           7.03
# 3                  RENT     5500.0           PERSONAL           7.43
# 4              MORTGAGE     3984.0  DEBTCONSOLIDATION          10.86
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# ...

# %%
features = df[["person_age", "person_income", "person_emp_exp", "person_home_ownership", "loan_amnt", "loan_intent",
               "loan_int_rate", "loan_percent_income", "cb_person_cred_hist_length", "credit_score", "previous_loan_defaults_on_file"]]

# %%
target = df['loan_status']

# %%
features
# Out:
#        person_age  person_income  person_emp_exp person_home_ownership  \
# 0            26.0       256862.0               2              MORTGAGE
# 1            23.0        70430.0               0              MORTGAGE
# 2            33.0        75456.0              10                  RENT
# 3            27.0        25052.0               7                  RENT
# 4            30.0        61291.0               8              MORTGAGE
# ...           ...            ...             ...                   ...
# 31495        25.0        84983.0               3                  RENT
# 31496        25.0       103044.0               0              MORTGAGE
# 31497        26.0        60634.0               6                  RENT
# 31498        22.0        61414.0               0              MORTGAGE
# 31499        22.0        80607.0               0                  RENT
#
#        loan_amnt        loan_intent  loan_int_rate  loan_percent_income  \
# ...

# %%
target
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 31495    0
# 31496    0
# 31497    0
# 31498    0
# 31499    1
# Name: loan_status, Length: 31500, dtype: int64

# %%
X = features.values
Y = target.values

# %%
X
# Out:
# array([[26.0, 256862.0, 2, ..., 2.0, 643, 'No'],
#        [23.0, 70430.0, 0, ..., 3.0, 623, 'Yes'],
#        [33.0, 75456.0, 10, ..., 9.0, 638, 'No'],
#        ...,
#        [26.0, 60634.0, 6, ..., 5.0, 653, 'No'],
#        [22.0, 61414.0, 0, ..., 3.0, 618, 'Yes'],
#        [22.0, 80607.0, 0, ..., 4.0, 659, 'No']], dtype=object)

# %%
X.shape
# Out:
# (31500, 11)

# %%
Y.shape
# Out:
# (31500,)

# %%
X = pd.get_dummies(features)

# %%
X
# Out:
#        person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 0            26.0       256862.0               2    35000.0          10.65
# 1            23.0        70430.0               0     6455.0          10.24
# 2            33.0        75456.0              10     7000.0           7.03
# 3            27.0        25052.0               7     5500.0           7.43
# 4            30.0        61291.0               8     3984.0          10.86
# ...           ...            ...             ...        ...            ...
# 31495        25.0        84983.0               3    12000.0          10.37
# 31496        25.0       103044.0               0     7200.0          13.57
# 31497        26.0        60634.0               6     8470.0          10.95
# 31498        22.0        61414.0               0    12000.0           7.90
# 31499        22.0        80607.0               0     8000.0          14.65
#
# ...

# %%
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
X
# Out:
# array([[-0.28856814,  1.98163245, -0.55805078, ..., -0.46033831,
#          1.01496917, -1.01496917],
#        [-0.78546481, -0.11764347, -0.88810954, ...,  2.17231541,
#         -0.9852516 ,  0.9852516 ],
#        [ 0.87085743, -0.06104932,  0.76218427, ..., -0.46033831,
#          1.01496917, -1.01496917],
#        ...,
#        [-0.28856814, -0.22794915,  0.10206674, ..., -0.46033831,
#          1.01496917, -1.01496917],
#        [-0.95109704, -0.21916613, -0.88810954, ...,  2.17231541,
#         -0.9852516 ,  0.9852516 ],
#        [-0.95109704, -0.00304764, -0.88810954, ..., -0.46033831,
#          1.01496917, -1.01496917]])

# %%
seed_value = 42
tf.random.set_seed(seed_value)    # For TensorFlow and Keras
np.random.seed(seed_value)        # For NumPy
random.seed(seed_value)
os.environ['PYTHONHASHSEED'] = str(seed_value)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=seed_value)

# %%
lg = LogisticRegression()
lg.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
lg.score = lg.score(X_test, Y_test)

# %%
lg.score
# Out:
# 0.8915873015873016

# %%
kn = KNeighborsClassifier()
kn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
kn.score = kn.score(X_test, Y_test)

# %%
kn.score
# Out:
# 0.8990476190476191

# %%
rf = RandomForestClassifier()
rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
rf.score = rf.score(X_test, Y_test)

# %%
rf.score
# Out:
# 0.9234920634920635

# %%
input_dim = X_train.shape[1]

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer='sgd',loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, Y, batch_size=32, epochs=30)
# Out:
# Epoch 1/30
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 0s 211us/step - accuracy: 0.8296 - loss: 0.3953
# Epoch 2/30
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 0s 205us/step - accuracy: 0.8941 - loss: 0.2327
# Epoch 3/30
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 0s 198us/step - accuracy: 0.8984 - loss: 0.2214
# Epoch 4/30
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 0s 202us/step - accuracy: 0.9025 - loss: 0.2155
# Epoch 5/30
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 0s 206us/step - accuracy: 0.9053 - loss: 0.2113
# Epoch 6/30
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 0s 207us/step - accuracy: 0.9066 - loss: 0.2078
# Epoch 7/30
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 0s 201us/step - accuracy: 0.9079 - loss: 0.2047
# Epoch 8/30
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 0s 202us/step - accuracy: 0.9089 - loss: 0.2018
# Epoch 9/30
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 0s 210us/step - accuracy: 0.9106 - loss: 0.1994
# Epoch 10/30
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 0s 204us/step - accuracy: 0.9114 - loss: 0.1974
# Epoch 11/30
# ...

# %%
model.evaluate(X_test, Y_test)
# Out:
# 197/197 ━━━━━━━━━━━━━━━━━━━━ 0s 199us/step - accuracy: 0.9135 - loss: 0.1859
# [0.18297703564167023, 0.9153968095779419]

# %%
test_df = pd.read_csv('test.csv')

# %%
test_df.dropna(inplace=True)

# %%
test_features = df[["person_age", "person_income", "person_emp_exp", "person_home_ownership", "loan_amnt", "loan_intent",
               "loan_int_rate", "loan_percent_income", "cb_person_cred_hist_length", "credit_score", "previous_loan_defaults_on_file"]]

# %%
X_tester = features.values
X_tester
# Out:
# array([[26.0, 256862.0, 2, ..., 2.0, 643, 'No'],
#        [23.0, 70430.0, 0, ..., 3.0, 623, 'Yes'],
#        [33.0, 75456.0, 10, ..., 9.0, 638, 'No'],
#        ...,
#        [26.0, 60634.0, 6, ..., 5.0, 653, 'No'],
#        [22.0, 61414.0, 0, ..., 3.0, 618, 'Yes'],
#        [22.0, 80607.0, 0, ..., 4.0, 659, 'No']], dtype=object)

# %%
X_tester = pd.get_dummies(test_features)

# %%
X_tester
# Out:
#        person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 0            26.0       256862.0               2    35000.0          10.65
# 1            23.0        70430.0               0     6455.0          10.24
# 2            33.0        75456.0              10     7000.0           7.03
# 3            27.0        25052.0               7     5500.0           7.43
# 4            30.0        61291.0               8     3984.0          10.86
# ...           ...            ...             ...        ...            ...
# 31495        25.0        84983.0               3    12000.0          10.37
# 31496        25.0       103044.0               0     7200.0          13.57
# 31497        26.0        60634.0               6     8470.0          10.95
# 31498        22.0        61414.0               0    12000.0           7.90
# 31499        22.0        80607.0               0     8000.0          14.65
#
# ...

# %%
X_tester = sc.fit_transform(X_tester)

# %%
X_tester
# Out:
# array([[-0.28856814,  1.98163245, -0.55805078, ..., -0.46033831,
#          1.01496917, -1.01496917],
#        [-0.78546481, -0.11764347, -0.88810954, ...,  2.17231541,
#         -0.9852516 ,  0.9852516 ],
#        [ 0.87085743, -0.06104932,  0.76218427, ..., -0.46033831,
#          1.01496917, -1.01496917],
#        ...,
#        [-0.28856814, -0.22794915,  0.10206674, ..., -0.46033831,
#          1.01496917, -1.01496917],
#        [-0.95109704, -0.21916613, -0.88810954, ...,  2.17231541,
#         -0.9852516 ,  0.9852516 ],
#        [-0.95109704, -0.00304764, -0.88810954, ..., -0.46033831,
#          1.01496917, -1.01496917]])

# %%
predictions = model.predict(X_tester)
# Out:
# 985/985 ━━━━━━━━━━━━━━━━━━━━ 0s 182us/step

# %%
predictions = np.where(predictions > 0.5, 1, 0)

# %%
predictions
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [1]])

# %%
np.set_printoptions(threshold= 1000)
predictions = predictions.reshape(1, -1)[0]
predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(Y, predictions)
mse = mean_squared_error(Y, predictions)

# %%
mse
# Out:
# 0.08066666666666666

# %%
mae
# Out:
# 0.08066666666666666

# %%
train_data = pd.read_csv('train.csv')  
test_data = pd.read_csv('test.csv')   

X = train_data.drop(['loan_status'], axis=1)  
Y = train_data['loan_status']

X = pd.get_dummies(X)
X_test = pd.get_dummies(test_data)


X_test = X_test.reindex(columns=X.columns, fill_value=0)


X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.2, random_state=42)


sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_val = sc.transform(X_val)
X_tester = sc.transform(X_test)


dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, Y_train)
dt_predictions = dt_model.predict(X_val)
dt_accuracy = accuracy_score(Y_val, dt_predictions)
print("Decision Tree Accuracy:", dt_accuracy)

svm_model = SVC(kernel='linear')
svm_model.fit(X_train, Y_train)
svm_predictions = svm_model.predict(X_val)
svm_accuracy = accuracy_score(Y_val, svm_predictions)
print("SVM Accuracy:", svm_accuracy)
# Out:
# Decision Tree Accuracy: 0.9249206349206349
# SVM Accuracy: 0.8933333333333333

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, Y_train)
rf_predictions = rf_model.predict(X_val)
rf_accuracy = accuracy_score(Y_val, rf_predictions)
print("Forest Accuracy:", rf_accuracy)
# Out:
# Forest Accuracy: 0.94

# %%
# test_predictions = dt_model.predict(X_tester)
test_predictions = rf_model.predict(X_tester)
sample_submission = pd.read_csv('submission.csv') 
sample_submission['loan_status'] = test_predictions 
sample_submission.to_csv('my_submission.csv', index=False)
